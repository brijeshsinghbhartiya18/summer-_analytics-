# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](...- ..._..._..._... KNN ..._frameD9QebW/RvL9TyRv0TFw9nz1b7bzryfoOh9i+fek6+L0L5X+oav1fxfy3p9Rw+/H6Xo+W+h4uiIkTCELK6u4mUbScRBJTEldw3ccwcW5svXNmzuUvbZIXH5f6vuOn86zunwpK7Xa8FyWi9LctBxffQkNGbNtVdata_..._..._..._..._..._..._..._..._..._..._..._..._..._..._..._..._..._..._..._..._..._..._...__..._..._..._..._..._..._..._... Discriminant Analysis - ..._..._..._..._..._..._..._..._... Component Analysis - ..._frameqAZv+QEjRXbmLKDeploPqouzcA1APn3O7MpxV+5QYCFEoMeRlZZ0p4J7YvNPiX2SXwi7BLbzNncoMsFdMsmL5/Hxct6zLepbLlsaGWvbUeqeQVnJPpR8B5ogOh7Z2DqCBKlJX/gKepScRGWja7Yp5jsjXqpf2omqreo1ebu1WHLPQYI5cgIdata_..._..._..._..._..._... Discriminant Analysis - ..._..._..._..._..._framePbOeK//CP/AMtK/wDpxDofRI+J6oibce2cly8LeZV/9SnSHgleMrxnoh4J4Ey4SvO7MIhxES2/qp/6omeqH0QTr9Yjf/jKfNrEwXUeidata_..._..._..._..._..._..._..._..._..._..._)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,..._..._...__..._framepn/YGe8G9uUIVNmm5c18ltSNciIOYpDIbAqJqKe7nbJwZ903bMhEdM7a3gtpzU5Nin6n6bAJdocZ1U762XLoOFR6NNnL3sMK6ibQJNnyIA77XSx7fTfwCERGHbcjDH1xklTjIRQIGpDR63JVxbYEjFQzMFJGWuhIe9Iv6ESpsO6Gs5QC6vsdata_..._..._..._..._..._..._..._..._..._..._...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
#your code here
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here
data_frame = pd.read_csv("Cars.csv")

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
#your code here
data_frame.shape
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
data_frame.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
#your code here
data_frame = data_frame.set_index('name')

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
#your code here
data_frame['mpg'].unique()
# Out:
# array([18. , 15. , 16. , 17. , 14. , 24. , 22. , 21. , 27. , 26. , 25. ,
#        10. , 11. ,  9. , 28. , 19. , 12. , 13. , 23. , 30. , 31. , 35. ,
#        20. , 29. , 32. , 33. , 17.5, 15.5, 14.5, 22.5, 24.5, 18.5, 29.5,
#        26.5, 16.5, 31.5, 36. , 25.5, 33.5, 20.5, 30.5, 21.5, 43.1, 36.1,
#        32.8, 39.4, 19.9, 19.4, 20.2, 19.2, 25.1, 20.6, 20.8, 18.6, 18.1,
#        17.7, 27.5, 27.2, 30.9, 21.1, 23.2, 23.8, 23.9, 20.3, 21.6, 16.2,
#        19.8, 22.3, 17.6, 18.2, 16.9, 31.9, 34.1, 35.7, 27.4, 25.4, 34.2,
#        34.5, 31.8, 37.3, 28.4, 28.8, 26.8, 41.5, 38.1, 32.1, 37.2, 26.4,
#        24.3, 19.1, 34.3, 29.8, 31.3, 37. , 32.2, 46.6, 27.9, 40.8, 44.3,
#        43.4, 36.4, 44.6, 40.9, 33.8, 32.7, 23.7, 23.6, 32.4, 26.6, 25.8,
#        23.5, 39.1, 39. , 35.1, 32.3, 37.7, 34.7, 34.4, 29.9, 33.7, 32.9,
#        31.6, 28.1, 30.7, 24.2, 22.4, 34. , 38. , 44. ])

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
#your code here
data_frame = data_frame.reset_index()
data_frame['horsePower/weight'] = data_frame['horsepower']/data_frame['weight']
data_frame = data_frame.set_index('horsePower/weight')

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,..._..._..._..._..._..._..._..._..._...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
#your code here
data_frame = data_frame.reset_index()
data_frame = data_frame.set_index('horsepower')
max_idx = data_frame.index.max()
data_frame.reset_index()
Car_max_hp = data_frame.loc[max_idx, 'name']
print(Car_max_hp)
# Out:
# pontiac grand prix

# %%
data_frame['horsepower'] = data_frame['horsePower/weight'] * data_frame['weight']

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
#your code here
cars_mpg_35 = len(data_frame[data_frame['mpg'] >= 35])
print(cars_mpg_35)
# Out:
# 36

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
#your code here
common_ori = data_frame[(data_frame['horsepower'] > 100) & data_frame['weight'] < 3000]
common = common_ori['origin'].mode()
print(common[0])
# Out:
# usa

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
#your code here
japan_cars = data_frame[data_frame['origin'] == 'japan']
mean = japan_cars['acceleration'].mean()
print(mean)
# Out:
# 16.17215189873418

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
#your code here
avg_mpg = data_frame.groupby('ml_model_year')['mpg'].mean()
high_mpg_year = avg_mpg.index.max()
high_mpg_val = avg_mpg.max()
print(high_mpg_year)
# Out:
# 82

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
#your code here
median_mpg = data_frame['mpg'].median()
above_med_mpg = data_frame[data_frame['mpg'] > median_mpg]
max_ratio = above_med_mpg.index.max()
best_cars = above_med_mpg[above_med_mpg.index == max_ratio]
print(best_cars)
# Out:
#             horsePower/weight           name   mpg  cylinders  displacement  \
# horsepower
# 132.0                0.045361  datsun 280-zx  32.7          6         168.0
#
#             weight  acceleration  model_year origin  horsepower
# horsepower
# 132.0         2910          11.4          80  japan       132.0

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
#your code here
avg_mpg = data_frame.groupby(['ml_model_year', 'origin'])['mpg'].mean().unstack()

plt.figure(figsize=(10, 6))
for origin in avg_mpg.columns:
    plt.plot(avg_mpg.index, avg_mpg[origin], marker='o', label=origin)

plt.title('Average MPG by Origin Over Years')
plt.xlabel('Model Year')
plt.ylabel('Average MPG')
plt.legend(title='Origin')
plt.show()

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
#your code here
data_frame['hp_to_weight_ratio'] = data_frame['horsepower'] / data_frame['weight']

data_frame = data_frame.reset_index(drop=True)

duplicates = data_frame['hp_to_weight_ratio'].duplicated().any()
print(f"Duplicates in hp_to_weight_ratio: {duplicates}")

sns.set_style("whitegrid")

plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(
    data=data_frame,
    x='horsepower',
    y='weight',
    hue='origin',
    size='mpg',
    hue_order=['japan', 'europe', 'usa'],
    sizes=(50, 500),  
    alpha=0.7  
)

plt.title('Horsepower vs. Weight of Cars by Origin and MPG', fontsize=14, pad=10)
plt.xlabel('Horsepower (hp)', fontsize=12)
plt.ylabel('Weight (lbs)', fontsize=12)
plt.legend(title='Origin', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
# Out:
# Duplicates in hp_to_weight_ratio: True

# %% [markdown]
# ### We define a “consistent” car ml_model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one ml_model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the ml_model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
#your code here
data_frame = data_frame.reset_index(drop=True)

year_counts = data_frame.groupby('name')['ml_model_year'].nunique()

multi_year_cars = year_counts[year_counts >= 2].index

if multi_year_cars.empty:
    print("No car ml_models appear in multiple years, so no consistent ml_models (std(mpg) < 1.0) can be identified.")
else:
    mpg_stats = data_frame[data_frame['name'].isin(multi_year_cars)].groupby('name').agg(
        appearances=('ml_model_year', 'nunique'),
        avg_mpg=('mpg', 'mean'),
        std_mpg=('mpg', 'std')
    )

    consistent_cars = mpg_stats[mpg_stats['std_mpg'] < 1.0]

    if consistent_cars.empty:
        print("No car ml_models with multiple years have std(mpg) < 1.0.")
    else:
        consistent_cars = consistent_cars.sort_values(by=['appearances', 'avg_mpg'], ascending=[False, False])
        
        min_std = consistent_cars['std_mpg'].min()
        result = consistent_cars[consistent_cars['std_mpg'] == min_std]
        
        print("Consistent car ml_models (std(mpg) < 1.0, multiple years):")
        print(result[['appearances', 'avg_mpg', 'std_mpg']].to_string())
# Out:
# Consistent car models (std(mpg) < 1.0, multiple years):
#               appearances  avg_mpg  std_mpg
# name
# datsun pl510            2     27.0      0.0

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,... Discriminant Analysis - ..._..._..._..._..._...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
